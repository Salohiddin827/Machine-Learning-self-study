# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

df = fetch_california_housing(as_frame=True).frame
df.sample()

pd.options.display.max_columns = 10

df.inf0()



#df.head() --- is to get the data from the first 5 column
#df.head(10) --- is to get the data from the first 10 column



#df.tail() --- is to get the data from the last 5 column
#df.tail(10) --- is to get the data from the last 10 column






# if data type        | includes only one data type like float64  and then it whole column will be float64 
# if mmixed data type | includes more than one dta type like int64 and object then it will be object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4k/5z6v2zwn1nj48whjd_0br84w0000gn/T/ipykernel_66133/1878306704.py in ?()
#       5 df.sample()
#       6
#       7 pd.options.display.max_columns = 10
#       8
# ----> 9 df.inf0()
#      10
#      11
#      12
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'inf0'
