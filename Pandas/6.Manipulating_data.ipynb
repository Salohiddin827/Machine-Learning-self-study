# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Mike','Alice','Bob'],
    'age': [30,45,80],
    'job': ['Programmer','Designer','Accountant']
    }
)
df = df.set_index('name')

# %%
df.loc['Salohiddin'] =[19,'ML engineer']

# %%
def my_function(x):
    if x%3==0:
        return x**2
    else:
        return x//2

# %%
df.age.apply(my_function)
# Out:
# name
# Mike           900
# Alice         2025
# Bob             40
# Salohiddin       9
# Name: age, dtype: int64

# %%
def my_function2(x):
    if x.endswith('r'):
        return 'Wuthout job'
    else:
        return 'has a job'

# %%
df.job.apply(my_function2)
# Out:
# name
# Mike          Wuthout job
# Alice         Wuthout job
# Bob             has a job
# Salohiddin    Wuthout job
# Name: job, dtype: object

# %%
df.age.apply(my_function)
# Out:
# name
# Mike           900
# Alice         2025
# Bob             40
# Salohiddin       9
# Name: age, dtype: int64

# %%
df.job.apply(my_function2)
# Out:
# name
# Mike          Wuthout job
# Alice         Wuthout job
# Bob             has a job
# Salohiddin    Wuthout job
# Name: job, dtype: object

# %%
df.drop('summary', axis=1)
# Out:
#             age          job
# name
# Mike         30   Programmer
# Alice        45     Designer
# Bob          80   Accountant
# Salohiddin   19  ML engineer

# %%
df.drop(['age','job'], axis = 1 )
# Out:
#                                 summary
# name
# Mike        Age ['age'], Jobs: ['jobs']
# Alice       Age ['age'], Jobs: ['jobs']
# Bob         Age ['age'], Jobs: ['jobs']
# Salohiddin  Age ['age'], Jobs: ['jobs']

# %%
df.at['Alice','age']=float('nan')
df,
