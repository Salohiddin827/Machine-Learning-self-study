# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Mike','Bob','Alice'],
    'age':[30,40,50],
    'job':['Programmer','Clerk','Designer']

})
# df = df.set_index('name')

# %%
df1 = pd.DataFrame({
    'a': [1, 2, 3]
}, index = [1,0,2])

df2 = pd.DataFrame({
    'a': [10, 20, 30]
},index = [1,2,0])

df.reset_index()
df.to_csv("my_data.csv",index=None)
pd.read_csv("my_data.csv",index_col=0)

df.to_json("my_json.json")
pd.read_json("my_json.json")
my_dict = df.to_dict(orient="records")
