# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Mike','Alice','Bob'],
    'age': [30,45,80],
    'job': ['Programmer','Designer','Accountant']
    }
)
df = df.set_index('name')
print(df)
# Out:
#        age         job
# name
# Mike    30  Programmer
# Alice   45    Designer
# Bob     80  Accountant

# %%
df = df.reset_index()
df = df.set_index('name')

# %%
df.loc['Alice','age']
# Out:
# np.int64(45)

# %%
df.iloc[1]
# Out:
# age          45
# job    Designer
# Name: Alice, dtype: object

# %%
df.at['Alice','age']
# Out:
# np.int64(45)

# %%
df.iat[1,0 ]
# Out:
# np.int64(45)

# %%
df.at['Mike','age']=60

# %%
df.loc['Alice']= [57,'Clerk']

# %%
df
# Out:
#        age         job
# name
# Mike    60  Programmer
# Alice   57       Clerk
# Bob     80  Accountant

# %%
df.loc['Salohiddin']= [19,'ML engineer']

# %%
df
# Out:
#             age          job
# name
# Mike         60   Programmer
# Alice        57        Clerk
# Bob          80   Accountant
# Salohiddin   19  ML engineer

# %%
df.iloc[0:4,1]
# Out:
# name
# Mike           Programmer
# Alice               Clerk
# Bob            Accountant
# Salohiddin    ML engineer
# Name: job, dtype: object

# %%
df['age'] = df.age *2

# %%
df['age'] = df.age /2

# %%
df
# Out:
#              age          job
# name
# Mike        60.0   Programmer
# Alice       57.0        Clerk
# Bob         80.0   Accountant
# Salohiddin  19.0  ML engineer
