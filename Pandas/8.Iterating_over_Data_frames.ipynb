# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Mike','Alice','Bob'],
    'age': [30,45,80],
    'job': ['Programmer','Designer','Accountant']
    }
)
df = df.set_index('name')

# %%
df.loc['Salohiddin'] =[19,'ML engineer']

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x10d359580>

# %%
for i, row in df.iterrows():
    print(row)
# Out:
# age            30
# job    Programmer
# Name: Mike, dtype: object
# age          45
# job    Designer
# Name: Alice, dtype: object
# age            80
# job    Accountant
# Name: Bob, dtype: object
# age             19
# job    ML engineer
# Name: Salohiddin, dtype: object

# %%
for i, col in df.items():
    print(col['Salohiddin'])
# Out:
# 19
# ML engineer
