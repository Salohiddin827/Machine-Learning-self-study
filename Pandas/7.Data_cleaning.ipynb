# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Mike','Alice','Bob'],
    'age': [30,45,80],
    'job': ['Programmer','Designer','Accountant']
    }
)
df = df.set_index('name')

# %%
df.loc['Salohiddin'] =[19,'ML engineer']

# %%
df.at['Alice','age']=float('nan')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Mike to Salohiddin
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     3 non-null      float64
#  1   job     4 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 268.0+ bytes

# %%
df
# Out:
#              age          job
# name
# Mike        30.0   Programmer
# Alice        NaN     Designer
# Bob         80.0   Accountant
# Salohiddin  19.0  ML engineer

# %%
df.dropna()
# df.dropna() this finction deletes all thw rows that has a NaN value
# Out:
#              age          job
# name
# Mike        30.0   Programmer
# Bob         80.0   Accountant
# Salohiddin  19.0  ML engineer

# %%
df.fillna(0)
# df.fillna(0) this fills rows that has a NaN value with any number you entered
# Out:
#              age          job
# name
# Mike        30.0   Programmer
# Alice        0.0     Designer
# Bob         80.0   Accountant
# Salohiddin  19.0  ML engineer

# %%
df.fillna(df.age.mean())
# Out:
#              age          job
# name
# Mike        30.0   Programmer
# Alice       43.0     Designer
# Bob         80.0   Accountant
# Salohiddin  19.0  ML engineer

# %%
df.at['Bob','job'] = None

# %%
df
# Out:
#              age          job
# name
# Mike        30.0   Programmer
# Alice        NaN     Designer
# Bob         80.0         None
# Salohiddin  19.0  ML engineer

# %%
df.notna(
    
)
# Out:
#               age    job
# name
# Mike         True   True
# Alice       False   True
# Bob          True  False
# Salohiddin   True   True

# %%
df[df.age.notna()]
# Out:
#              age          job
# name
# Mike        30.0   Programmer
# Bob         80.0         None
# Salohiddin  19.0  ML engineer

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x1200598b0>

# %%
for i , row in df.iterrows():
    print(row)
# Out:
# age          30.0
# job    Programmer
# Name: Mike, dtype: object
# age         NaN
# job    Designer
# Name: Alice, dtype: object
# age    80.0
# job    None
# Name: Bob, dtype: object
# age           19.0
# job    ML engineer
# Name: Salohiddin, dtype: object
