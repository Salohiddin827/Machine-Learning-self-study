# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = np.array([
    [3, 42, 5],
    [2, 111, 6],
    [7, 84, 9]
])

sns.heatmap(data, annot=True, fmt="d", cmap="coolwarm")

plt.show()
